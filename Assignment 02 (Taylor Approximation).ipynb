# %% [markdown]
# # [Submission]
#
# 1.
# Write a python code,
# make a comment,
# present results for each meaningful block of your code at Jupyter Notebook.
#
#   [New > Python 3]
#
#
# 2.
# Export your Jupyter Notebook file as PDF file at Jupyter Notebook.
#
#   [Download as > PDF via LaTeX (.pdf)]
#
#
# 3.
# Turn in your PDF file to the assignment at Google Classroom.
#
#   [Add > file]
#
#
#
# # [Taylor Approximation]
#
#
#
#  1. Define a differentiable function that maps from real number to real number.
#  2. Define a domain of the function.
#  3. Plot the function.
#  4. Select a point within the domain.
#  5. Mark the selected point on the function.
#  6. Define the first-order Taylor approximation at the selected point.
#  7. Plot the Taylor approximation with the same domain of the original function.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Define a differentiable function that maps from real number to real number.
#
#    → The function is $\sin x$

# %% [markdown]
# ### 2. Define a domain of the function.
#
#  →  a domain of function  is  $[0, {\pi \over 6}, {\pi \over 4}, {\pi \over 3}, {\pi \over 2}, {2\pi \over 3}, {3\pi \over 4}, {5\pi \over 6}, {\pi}, {7\pi \over 6}, {5\pi \over 4}, {4\pi \over 3}, {3\pi \over 2}, {5\pi \over 3}, {7\pi \over 4}, {11\pi \over 6}, {2\pi}]$

# %% [markdown]
# ### 3. Plot the function.

# %%
x=np.arange(0,2*np.pi,0.01)
y=np.sin(x)
plt.plot(x,y)

# %% [markdown]
# ### 4. Select a point within the domain.
#  →  The selected point is  $({5π \over 6},{1\over2})$

# %% [markdown]
# ### 5. Mark the selected point on the function.

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.set_title(' y=$\sin x$')

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.text(2, -9/6+3/2, 'The selected point')

ax.plot([5*np.pi/6], [1/2], 'o')
ax.annotate('(5π/6, 1/2)', xy=(5*np.pi/6, 1/2), xytext=(2, -4/3+3/2),
            arrowprops=dict(facecolor='black', shrink=0.005))

ax.axis([0, 2*np.pi, -1, 1])

x=np.arange(0,2*np.pi,0.01)
y=np.sin(x)

plt.plot(x,y)

plt.show()

# %% [markdown]
# ### 6. Define the first-order Taylor approximation at the selected point.
#
#  suppose $f : R^n→R$
#
#  the first-order Taylor approximation :
#
#  $\widehat{f}(x)=f(x)+{\partial f \over\partial x_1}(z)( x_1- z_1) +  \cdots  + {\partial f \over\partial x_n}(z)( x_n- z_n) $
#
#   n is 1 because $ f(x)=sinx $
#
#  therefore  $\widehat{f}(x)=f({5π\over6})+{\partial f \over\partial x}({5π\over6})( x- {5π\over6})$
#
#
#  ∴ $\widehat{f}(x)={1\over2}-{\sqrt{3}\over2}( x- {5π\over6})$

# %% [markdown]
# ### 7. Plot the Taylor approximation with the same domain of the original function.

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.set_title(' y=$\sin x$')

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.text(2, -9/6+3/2, 'The selected point')

ax.plot([5*np.pi/6], [1/2], 'o')
ax.annotate('(5π/6, 1/2)', xy=(5*np.pi/6, 1/2), xytext=(2, -4/3+3/2),
            arrowprops=dict(facecolor='black', shrink=0.005))

ax.axis([0, 2*np.pi, -1, 1])

x1=np.arange(0,2*np.pi,0.01)
y1=np.sin(x1)

plt.plot(x1,y1)

x2=np.arange(0,2*np.pi,0.01)
y2=1/2-((3**(0.5))/2)*(x2- 5*np.pi/6)

plt.plot(x2,y2)

plt.show()
